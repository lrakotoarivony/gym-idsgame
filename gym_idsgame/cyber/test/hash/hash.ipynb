# %%
from gym_idsgame.cyber.hash import attack_hash, defend_hash
from gym_idsgame.cyber.hash import simulate_attack_hash
from random import choice
import time

# %%
defend_hash("princess",1)
# Out:
# ('pRincess',
#  '25368d0aa00da722ed681f32803a9c3fed68bdf6fe7f4e141c9fddef5d52af75')

# %%
simulate_attack_hash(2,1)
# Out:
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-01-24 11:44) 2.500g/s 2880p/s 2880c/s 2880C/s Hpassword..princess17
# Session completed.
# True

# %%
guess = attack_hash(2)
# Out:
# Using default input encoding: UTF-8

# %% [markdown]
# min(3,1)

# %%
with open('short_ech.txt') as f:
    alist = [line.rstrip() for line in f]

count = 0
for i in range(100):
    password = choice(alist)
    answer, _ = defend_hash(password, 1)
    guess = attack_hash(2)
    if answer == guess:
        count += 1

print(f'Le pourcentage de réussite est de {count}%')
# Out:
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Le pourcentage de réussite est de 100%
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8

# %%
for attack in range(3):
    for defend in range(3):
        count = 0
        start = time.time()
        for _ in range(100):
            if simulate_attack_hash(attack,defend):
                count+=1
        end = time.time()
        time_duration = end - start
        win_perc = count
        print(attack,defend)
        print(win_perc,time_duration / 100)
        print('_______________')
# Out:
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-02-03 06:58) 50.00g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-02-03 06:58) 25.00g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-02-03 06:58) 50.00g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-02-03 06:58) 33.33g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-02-03 06:58) 50.00g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# 0 0
# 47 0.11684627056121827
# _______________
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 300.0p/s 300.0c/s 300.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# 0 1
# 0 0.1474514365196228
# _______________
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 60.00p/s 60.00c/s 60.00C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:58) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# 0 2
# 0 0.161119966506958
# _______________
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-02-03 06:59) 33.33g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-02-03 06:59) 50.00g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# Using default input encoding: UTF-8
# 1 0
# 100 0.15070754051208496
# _______________
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 300.0p/s 300.0c/s 300.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 60.00p/s 60.00c/s 60.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 300.0p/s 300.0c/s 300.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 300.0p/s 300.0c/s 300.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# 1 1
# 0 0.20899834156036376
# _______________
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 60.00p/s 60.00c/s 60.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 100.0p/s 100.0c/s 100.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 75.00p/s 75.00c/s 75.00C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 06:59) 0g/s 150.0p/s 150.0c/s 150.0C/s password..princess
# Session completed.
# Using default input encoding: UTF-8
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# ...
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 1g 0:00:00:00 DONE (2022-02-03 07:00) 25.00g/s 9600p/s 9600c/s 9600C/s password..Princessp
# Session completed.
# 2 1
# 100 0.1731348776817322
# _______________
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 07:00) 0g/s 118413p/s 118413c/s 118413C/s sncess..iloveÿou
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 07:00) 0g/s 118413p/s 118413c/s 118413C/s sncess..iloveÿou
# Session completed.
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 07:00) 0g/s 111012p/s 111012c/s 111012C/s sncess..iloveÿou
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 07:00) 0g/s 77226p/s 77226c/s 77226C/s password..iloveÿou
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 07:00) 0g/s 74008p/s 74008c/s 74008C/s password..iloveÿou
# Session completed.
# Will run 2 OpenMP threads
# Press Ctrl-C to abort, or send SIGUSR1 to john process for status
# 0g 0:00:00:00 DONE (2022-02-03 07:00) 0g/s